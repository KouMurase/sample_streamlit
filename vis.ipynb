# %%
import pandas as pd
import matplotlib.pyplot as plt 
import plotly

import streamlit as st

# %%
data = pd.read_csv("./input/data_2024.csv", encoding="shift-jis")

# %%
data.loc[data.index[2], :]
# Out:
# ダウンロードした時刻：2024/02/24 16:14:30    NaN
# Name: (nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan), dtype: object

# %%
data.loc[data.index[3], :]
# Out:
# ダウンロードした時刻：2024/02/24 16:14:30    均質番号
# Name: (nan, nan, 品質情報, 均質番号, nan, 品質情報, 均質番号, nan, 品質情報, 均質番号, nan, 現象なし情報, 品質情報), dtype: object

# %%
data.loc[data.index[1], :]
# Out:
# ダウンロードした時刻：2024/02/24 16:14:30    日照時間(時間)
# Name: (年月日, 平均気温(℃), 平均気温(℃), 平均気温(℃), 最高気温(℃), 最高気温(℃), 最高気温(℃), 最低気温(℃), 最低気温(℃), 最低気温(℃), 日照時間(時間), 日照時間(時間), 日照時間(時間)), dtype: object

# %%
data = pd.read_csv("./input/data_2024.csv", encoding="shift-jis", header=2)
data = data.drop(data.index[0:2], axis=0)
data
# Out:
#           年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 2   2024/1/23      9.0         8         1     13.9         8         1
# 3   2024/1/24      4.5         8         1      8.4         8         1
# 4   2024/1/25      4.2         8         1      9.6         8         1
# 5   2024/1/26      6.2         8         1     12.0         8         1
# 6   2024/1/27      7.2         8         1     12.2         8         1
# 7   2024/1/28      6.0         8         1      9.6         8         1
# 8   2024/1/29      6.8         8         1     11.9         8         1
# 9   2024/1/30      7.7         8         1     13.3         8         1
# 10  2024/1/31      9.3         8         1     14.1         8         1
# 11   2024/2/1      9.8         8         1     16.3         8         1
# 12   2024/2/2      5.0         8         1      7.6         8         1
# 13   2024/2/3      6.9         8         1     11.7         8         1
# 14   2024/2/4      4.9         8         1      6.9         8         1
# 15   2024/2/5      3.0         8         1      6.2         8         1
# 16   2024/2/6      3.4         8         1      5.4         8         1
# 17   2024/2/7      4.7         8         1      9.6         8         1
# 18   2024/2/8      5.7         8         1     11.3         8         1
# 19   2024/2/9      6.8         8         1     11.3         8         1
# 20  2024/2/10      7.1         8         1     12.4         8         1
# 21  2024/2/11      8.1         8         1     12.8         8         1
# 22  2024/2/12      7.3         8         1     12.7         8         1
# 23  2024/2/13      9.6         8         1     17.3         8         1
# 24  2024/2/14     10.9         8         1     18.5         8         1
# 25  2024/2/15     14.4         8         1     21.1         8         1
# 26  2024/2/16     10.6         8         1     17.0         8         1
# 27  2024/2/17      9.0         8         1     13.6         8         1
# 28  2024/2/18     13.4         8         1     18.8         8         1
# 29  2024/2/19     15.0         8         1     17.2         8         1
# 30  2024/2/20     18.1         8         1     23.7         8         1
# 31  2024/2/21      8.7         8         1     13.2         8         1
# 32  2024/2/22      5.5         8         1      8.0         8         1
# 33  2024/2/23      2.8         8         1      4.0         8         1
#
#     最低気温(℃) 最低気温(℃).1 最低気温(℃).2  日照時間(時間) 日照時間(時間).1 日照時間(時間).2 日照時間(時間).3
# 2       5.5         8         1       7.9          0          8          1
# 3       1.1         8         1       5.8          0          8          1
# 4      -1.1         8         1       9.3          0          8          1
# 5       1.8         8         1       9.4          0          8          1
# 6       2.9         8         1       9.2          0          8          1
# 7       2.8         8         1       1.7          0          8          1
# 8       2.4         8         1       9.3          0          8          1
# 9       4.0         8         1       9.0          0          8          1
# 10      2.7         8         1       9.3          0          8          1
# 11      5.0         8         1       5.0          0          8          1
# 12      3.3         8         1       0.4          0          8          1
# 13      3.4         8         1       8.7          0          8          1
# 14      2.6         8         1       0.0          0          8          1
# 15      0.3         8         1       0.0          0          8          1
# 16      0.8         8         1       0.0          0          8          1
# 17     -0.1         8         1       9.2          0          8          1
# 18      1.2         8         1       6.9          0          8          1
# 19      2.5         8         1       6.9          0          8          1
# 20      1.8         8         1       9.5          0          8          1
# 21      4.3         8         1       6.4          0          8          1
# 22      3.6         8         1       9.0          0          8          1
# 23      1.6         8         1       9.7          0          8          1
# 24      4.2         8         1       8.1          0          8          1
# 25      6.1         8         1       7.7          0          8          1
# 26      6.2         8         1       8.8          0          8          1
# 27      4.6         8         1       2.1          0          8          1
# 28      9.2         8         1       6.9          0          8          1
# 29     12.8         8         1       0.1          0          8          1
# 30     12.8         8         1       5.2          0          8          1
# 31      7.3         8         1       0.0          0          8          1
# 32      3.6         8         1       0.0          0          8          1
# 33      1.7         8         1       0.0          0          8          1
